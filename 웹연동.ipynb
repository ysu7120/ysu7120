# %%
# !pip install streamlit -q
# !pip install pyngrok
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 33.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 KB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 KB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.3 MB/s eta 0:00:00
#   Building wheel for validators (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyngrok
#   Downloading pyngrok-5.2.1.tar.gz (761 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 761.3/761.3 KB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from pyngrok) (6.0)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.2.1-py3-none-any.whl size=19792 sha256=7879ea51c498fcef5b3d1ac57fac7ab03c489a4227580cd0b73485947149a03b
#   Stored in directory: /root/.cache/pip/wheels/5d/f2/70/526da675d32f17577ec47ac4c663084efe39d47c826b6c3bb1
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-5.2.1

# %%
from pyngrok import ngrok

ngrok.set_auth_token('2L27YaPkGahXsWcWcWL8mFOl6m9_5iLnUXVu7izCia8L2zxYL')

# %%
# %%writefile app2.py

import streamlit as st
import tensorflow as tf
from PIL import Image, ImageOps
import numpy as np
from tensorflow.keras.applications.imagenet_utils import decode_predictions

resnet50_pre = tf.keras.applications.resnet.ResNet50(weights = "imagenet", input_shape=(224, 224, 3))

st.title('아보카도 분류 인공지능 웹페이지')
file = st. file_uploader('이미지를 올려주세요', type=['jpg','png'])

if file is None:
  st.text('이미지를 먼저 올려주세요.')
else:
  image = Image.open(file)
  st.image(image, use_column_width=True)
  img_resized = ImageOps.fit(image, (224,224), Image.ANTIALIAS)
  img_resized = img_resized.convert('RGB')
  img_resized = np.asarray(img_resized)

  pred = resnet50_pre.predict(img_resized.reshape([1,224,224,3]))
  decoded_pred = decode_predictions(pred)
  results = ''
  for i, instance in enumerate(decoded_pred[0]):
    results += '{}위: {} ({:.2f}%)'.format(i+1, instance[1], instance[2]*100)
  st.success(results)
# Out:
# Writing app2.py

# %%
# !ls
# Out:
# app2.py  sample_data

# %%
# !cat app2.py
# Out:
# import streamlit as st
# import tensorflow as tf
# from PIL import Image, ImageOps
# import numpy as np
# from tensorflow.keras.applications.imagenet_utils import decode_predictions
#
# resnet50_pre = tf.keras.applications.resnet.ResNet50(weights = "imagenet", input_shape=(224, 224, 3))
#
# st.title('이미지 분류 인공지능 웹페이지')
# file = st. file_uploader('이미지를 올려주세요', type=['jpg','png'])
#
# if file is None:
#   st.text('이미지를 먼저 올려주세요.')
# else:
#   image = Image.open(file)
#   st.image(image, use_column_width=True)
#   img_resized = ImageOps.fit(image, (224,224), Image.ANTIALIAS)
#   img_resized = img_resized.convert('RGB')
#   img_resized = np.asarray(img_resized)
#
#   pred = resnet50_pre.predict(img_resized.reshape([1,224,224,3]))
#   decoded_pred = decode_predictions(pred)
#   results = ''
#   for i, instance in enumerate(decoded_pred[0]):
#     results += '{}위: {} ({:.2f}%)'.format(i+1, instance[1], instance[2]*100)
#   st.success(results)

# %%
# !nohup streamlit run app2.py --server.port 80 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
url = ngrok.connect(port='80')
url
# Out:
# ERROR:pyngrok.process.ngrok:t=2023-01-31T01:34:38+0000 lvl=eror msg="failed to auth" obj=tunnels.session err="Your account is limited to 1 simultaneous ngrok agent session.\nActive ngrok agent sessions in region 'us':\n  - ts_2L4MqRZj34ceuOY7TOeArCvp995 (34.126.72.88)\r\n\r\nERR_NGROK_108\r\n"
# ERROR:pyngrok.process.ngrok:t=2023-01-31T01:34:38+0000 lvl=eror msg="failed to reconnect session" obj=csess id=77d2a981e863 err="Your account is limited to 1 simultaneous ngrok agent session.\nActive ngrok agent sessions in region 'us':\n  - ts_2L4MqRZj34ceuOY7TOeArCvp995 (34.126.72.88)\r\n\r\nERR_NGROK_108\r\n"
# ERROR:pyngrok.process.ngrok:t=2023-01-31T01:34:38+0000 lvl=eror msg="session closing" obj=tunnels.session err="Your account is limited to 1 simultaneous ngrok agent session.\nActive ngrok agent sessions in region 'us':\n  - ts_2L4MqRZj34ceuOY7TOeArCvp995 (34.126.72.88)\r\n\r\nERR_NGROK_108\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# <ipython-input-7-2020b1cbcc3d> in <module>
# ----> 1 url = ngrok.connect(port='80')
#       2 url
#
# /usr/local/lib/python3.8/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     265         options.pop("bind_tls")
#     266
# --> 267     api_url = get_ngrok_process(pyngrok_config).api_url
#     268
#     269     logger.debug("Creating tunnel with options: {}".format(options))
#
# /usr/local/lib/python3.8/dist-packages/pyngrok/ngrok.py in get_ngrok_process(pyngrok_config)
#     162     install_ngrok(pyngrok_config)
#     163
# --> 164     return process.get_process(pyngrok_config)
#     165
#     166
#
# /usr/local/lib/python3.8/dist-packages/pyngrok/process.py in get_process(pyngrok_config)
#     301         return _current_processes[pyngrok_config.ngrok_path]
#     302
# --> 303     return _start_process(pyngrok_config)
#     304
#     305
#
# /usr/local/lib/python3.8/dist-packages/pyngrok/process.py in _start_process(pyngrok_config)
#     470
#     471         if ngrok_process.startup_error is not None:
# --> 472             raise PyngrokNgrokError("The ngrok process errored on start: {}.".format(ngrok_process.startup_error),
#     473                                     ngrok_process.logs,
#     474                                     ngrok_process.startup_error)
#
# PyngrokNgrokError: The ngrok process errored on start: Your account is limited to 1 simultaneous ngrok agent session.\nActive ngrok agent sessions in region 'us':\n  - ts_2L4MqRZj34ceuOY7TOeArCvp995 (34.126.72.88)\r\n\r\nERR_NGROK_108\r\n.
