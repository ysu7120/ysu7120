# %%
n,m = list(map(int,input().split())) #지정할 두수
 
s = [] #리스트
 
def dfs(): #dfs깊이탐색
    if len(s)==m: #m의 길이가 될때 출력하는 함수
        print(' '.join(map(str,s)))
        return
    
    for i in range(1,n+1): #1~n까지의 수를 트래킹
        if i not in s:     
            s.append(i)    #수를 리스트에 추가
            dfs()
            s.pop()        #pop을 활용하여 리스트의 끝자리수 제거
 
dfs()
