# %%
N=int(input())
grade=[]
for i in range(N):
  x,y=map(int,input().split())
  grade.append((x,y))

for j in range(N):
  rank=1
  for k in range(N):
    if grade[j][0]<grade[k][0] and grade[j][1]<grade[k][1]:
      rank+=1
  print(rank,end=" ")
# Out:
# 5
# 55 185
# 58 183
# 88 186
# 60 175
# 46 155
# 2 2 1 2 5
