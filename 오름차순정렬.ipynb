# %%
N=int(input())
lst=[]
for i in range(N):
    k=int(input())
    lst.append(k)
for i in range(N):
  j=min(lst)
  print(j)
  lst.remove(j)
# Out:
# 6
# 1
# 1
# 3
# 4
# 4
# 5
# 1
# 1
# 3
# 4
# 4
# 5
