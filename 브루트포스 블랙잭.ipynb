# %%
N,M=map(int,input().split())
Deck=list(map(int,input().split()))
sum=0
for i in range(N):
  for j in range(i+1,N):
    for k in range(j+1,N):
      if Deck[i]+Deck[j]+Deck[k]>M:
        continue
      else:
        sum=(max(sum,Deck[i]+Deck[j]+Deck[k]))

print(sum)
# Out:
# 5 21
# 5 6 7 8 9
# 21
