# %%
from insta.selenium_crawling import selenium_postid_crawler
from insta.bs4_crawling import bs4_crawler
from insta.ext_data import processing
import time

# %%
article_ids = selenium_postid_crawler()

save_path = bs4_crawler(article_ids)

max_place = processing(save_path, len(article_ids))

print(max_place)
# Out:
# 지정 횟수 초과! IP 차단 혹은 로딩 오류 확인 요망.
# article_ids = 3967
# 1. CmmPo51pN4U 완료
# 2. CmmNwMRvme8 완료
# 3. CmmEP6IrHQa 완료
# 4. CmmPg-VJRZY 완료
# 5. CmmUSkqSbsQ 완료
# 6. CmmQgFYPa23 완료
# 7. CmmPiPgh2bU 완료
# 8. CmmPj_QJbC0 완료
# 9. CmmPw9rP9GW 완료
# 10. CmmRbx6yvhZ 완료
# 11. CmmPRcgPWoZ 완료
# 12. CmmPvH4v_1i 완료
# 13. CmmTr5Nvwwa 완료
# 14. CmmOvtBBLrZ 완료
# 15. CmmUiesvdrT 완료
# 16. CmmQ_vUp5M1 완료
# 17. Cmjay_TJfAU 완료
# 18. Cml2_6WrWpX 완료
# 19. CmmBvtKSI74 완료
# 20. CmmPW-PBuEx 완료
# 21. CmmVGVLB6Lj 완료
# 22. CmmRlPyvjVF 완료
# 23. CmmOgFAvObb 완료
# 24. CmmOtMBJNdz 완료
# 25. CmmPA8uBBq4 완료
# 26. CmmUvRXSpcu 완료
# 27. CmlW9HzB8RL 완료
# 28. CmmUTjApAlF 완료
# 29. CmmSdd6PJQI 완료
# 30. CmmDgLwJoph 완료
# 31. CmmGWK_pMta 완료
# 32. CmjkQI9yZKX 완료
# 33. CmmLcxdSSGW 완료
# 34. CmmOhFbJhSG 완료
# 35. CmmOKnAh1ek 완료
# 36. CmmNHzMJUVq 완료
# 37. CmmE31nJhl8 완료
# 38. CmmT_CTvbLH 완료
# 39. CmmTpcnPWdv 완료
# 40. CmmTgghSBdS 완료
# 41. CmmPSyQy-1n 완료
# 42. CmmLYzuvh6p 완료
# 43. CmmUjG5PRXu 완료
# 44. CmmM4AeP8M_ 완료
# 45. Cmk32Rwvkzo 완료
# ...
